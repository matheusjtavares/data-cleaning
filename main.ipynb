# %%
from models.outlierCleaner import outlierCleaner
from models.dataPlotter import dataPlotter

# %%
data_plotter = dataPlotter(file_name='T1.csv')
outlier_cleaner = outlierCleaner(file_name='T1.csv')
# Out:
# d:\Projects\data-cleaning

# %%
data_plotter.make_box_plot(target='Wind Speed (m/s)')
outlier_cleaner.test_for_normal('Wind Speed (m/s)')
data_plotter.make_histogram(target='Wind Speed (m/s)',bins=40)
# Out:
# Statistic: 0.04573976328415442, p-value: 2.6451761797863906e-92
# The column does not follow a normal distribution (reject H0)
# True

# %%
data_plotter.make_histogram(target='Theoretical_Power_Curve (KWh)',bins=40)
outlier_cleaner.test_for_normal('Theoretical_Power_Curve (KWh)')
# Out:
# Statistic: 0.1376899119714925, p-value: 0.0
# The column does not follow a normal distribution (reject H0)
# False
