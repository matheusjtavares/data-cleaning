# %%
from models.outlierCleaner import outlierCleaner
from models.dataPlotter import dataPlotter

# %%
data_plotter = dataPlotter(file_name='T1.csv')
outlier_cleaner = outlierCleaner(file_name='T1.csv')
# Out:
# d:\Projects\data-cleaning

# %%
data_plotter.make_histogram(target= 'Potência Ativa (kW)',bins=40)
data_plotter.make_histogram(target='Velocidade do Vento (m/s)',bins=40)
data_plotter.make_histogram(target='Potência Teórica (kW)',bins=40)
data_plotter.make_histogram(target='Direção do Vento(°)',bins=40)
# Out:
# True

# %%
outlier_cleaner.test_for_normal('Potência Teórica (kW)')
# Out:
# Statistic: 0.1376899119714925, p-value: 0.0
# The column does not follow a normal distribution (reject H0)
# False

# %%
outlier_cleaner.z_score(target='Velocidade do Vento (m/s)')
# Out:
# (                  Potência Ativa (kW)  Velocidade do Vento (m/s)  \
#  TS
#  17 01 2018 20:50          3460.934082                  20.408730
#  17 01 2018 21:00          3460.278076                  20.311640
#  17 01 2018 21:20          3461.021973                  21.735920
#  17 01 2018 21:30          3460.617920                  20.480160
#  17 01 2018 21:40          3461.166016                  21.158911
#  ...                               ...                        ...
#  24 12 2018 20:10          3599.202881                  20.886930
#  24 12 2018 20:20          3599.352051                  20.566700
#  24 12 2018 20:30          3598.977051                  20.452000
#  24 12 2018 20:40          3599.501953                  21.018150
#  24 12 2018 20:50          3599.791016                  20.427059
#
#                    Potência Teórica (kW)  Direção do Vento(°)   Z_Score
#  TS
#  17 01 2018 20:50                 3600.0           190.896606  3.040046
# ...

# %%
a,b=outlier_cleaner.modified_z_score(target='Velocidade do Vento (m/s)',limit=3)

# %%
outlier_cleaner.source_data.describe()
# Out:
#        Potência Ativa (kW)  Velocidade do Vento (m/s)  Potência Teórica (kW)  \
# count         50530.000000               50530.000000           50530.000000
# mean           1307.684332                   7.557952            1492.175463
# std            1312.459242                   4.227166            1368.018238
# min              -2.471405                   0.000000               0.000000
# 25%              50.677890                   4.201395             161.328167
# 50%             825.838074                   7.104594            1063.776283
# 75%            2482.507568                  10.300020            2964.972462
# max            3618.732910                  25.206011            3600.000000
#
#        Direção do Vento(°)       Z_Score  Modified_Z_Score
# count         50530.000000  5.053000e+04      5.053000e+04
# mean            123.687559 -1.102445e-16      1.008389e-01
# std              93.443736  1.000000e+00      9.402330e-01
# ...

# %%
outlier_cleaner.grubbs_test(target='Velocidade do Vento (m/s)')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 outlier_cleaner.grubbs_test(target='Velocidade do Vento (m/s)')
#
# File d:\Projects\data-cleaning\models\outlierCleaner.py:74, in outlierCleaner.grubbs_test(self, target, alpha)
#      72     critical_value = ((N - 1) * np.sqrt(t_value**2)) / (np.sqrt(N) * np.sqrt(N - 2 + t_value**2))
#      73     return G > critical_value
# ---> 74 outliers = df[df[target].apply(lambda x: grubbs_method(df[target]))]
#      75 execution_time = tm.time() - t
#      77 return outliers,execution_time
#
# File d:\Projects\data-cleaning\venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
# ...
